# %%
# !wget https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz
# Out:
# --2020-10-21 18:26:03--  https://s3.amazonaws.com/fast-ai-imageclas/imagenette2.tgz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.39.230
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.39.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1556914727 (1.4G) [application/x-tar]
# Saving to: ‘imagenette2.tgz’
#
# imagenette2.tgz     100%[===================>]   1.45G  14.0MB/s    in 1m 49s
#
# 2020-10-21 18:27:53 (13.6 MB/s) - ‘imagenette2.tgz’ saved [1556914727/1556914727]

# %%
# !tar -xf imagenette2.tgz

# %%
from keras.preprocessing.image import ImageDataGenerator

# create a new generator

imagegen = ImageDataGenerator()

#load train data

train = imagegen.flow_from_directory("imagenette2/train/", class_mode="categorical", shuffle=False, batch_size=128, target_size=(224,224))

#load val data

val = imagegen.flow_from_directory("imagenette2/val/",class_mode="categorical",shuffle=False, batch_size=128, target_size=(224,224) )
# Out:
# Found 9469 images belonging to 10 classes.
# Found 3925 images belonging to 10 classes.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, InputLayer, BatchNormalization, Dropout

# build a sequential model
model = Sequential()
model.add(InputLayer(input_shape=(224, 224, 3)))

# 1st conv block
model.add(Conv2D(25, (5, 5), activation='relu', strides=(1, 1), padding='same'))
model.add(MaxPool2D(pool_size=(2, 2), padding='same'))
# 2nd conv block
model.add(Conv2D(50, (5, 5), activation='relu', strides=(2, 2), padding='same'))
model.add(MaxPool2D(pool_size=(2, 2), padding='same'))
model.add(BatchNormalization())
# 3rd conv block
model.add(Conv2D(70, (3, 3), activation='relu', strides=(2, 2), padding='same'))
model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
model.add(BatchNormalization())
# ANN block
model.add(Flatten())
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=100, activation='relu'))
model.add(Dropout(0.25))
# output layer
model.add(Dense(units=10, activation='softmax'))

# compile model
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
# fit on data for 30 epochs
model.fit_generator(train, epochs=30, validation_data=val)
# Out:
# WARNING:tensorflow:From <ipython-input-6-5d5be64feff7>:30: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
#  2/74 [..............................] - ETA: 6s - loss: 0.9223 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0631s vs `on_train_batch_end` time: 0.1057s). Check your callbacks.
# 74/74 [==============================] - 76s 1s/step - loss: 2.7118 - accuracy: 0.1463 - val_loss: 2.2969 - val_accuracy: 0.1383
# Epoch 2/30
# 74/74 [==============================] - 76s 1s/step - loss: 2.1738 - accuracy: 0.2311 - val_loss: 2.2899 - val_accuracy: 0.2048
# Epoch 3/30
# 74/74 [==============================] - 73s 982ms/step - loss: 2.0109 - accuracy: 0.3021 - val_loss: 2.2310 - val_accuracy: 0.2140
# Epoch 4/30
# 74/74 [==============================] - 72s 972ms/step - loss: 1.7268 - accuracy: 0.4203 - val_loss: 2.2546 - val_accuracy: 0.2038
# Epoch 5/30
# 74/74 [==============================] - 70s 948ms/step - loss: 1.5413 - accuracy: 0.4678 - val_loss: 2.0809 - val_accuracy: 0.2966
# Epoch 6/30
# 74/74 [==============================] - 69s 938ms/step - loss: 1.3246 - accuracy: 0.5505 - val_loss: 1.7649 - val_accuracy: 0.4211
# Epoch 7/30
# 74/74 [==============================] - 70s 950ms/step - loss: 1.1300 - accuracy: 0.6230 - val_loss: 2.3714 - val_accuracy: 0.3101
# Epoch 8/30
# 74/74 [==============================] - 71s 956ms/step - loss: 1.0460 - accuracy: 0.6436 - val_loss: 2.3463 - val_accuracy: 0.3450
# Epoch 9/30
# 74/74 [==============================] - 70s 941ms/step - loss: 0.7741 - accuracy: 0.7433 - val_loss: 1.7589 - val_accuracy: 0.4642
# Epoch 10/30
# 74/74 [==============================] - 69s 939ms/step - loss: 0.7217 - accuracy: 0.7556 - val_loss: 2.0103 - val_accuracy: 0.4268
# Epoch 11/30
# 74/74 [==============================] - 70s 941ms/step - loss: 0.5443 - accuracy: 0.8238 - val_loss: 1.9138 - val_accuracy: 0.4688
# Epoch 12/30
# 74/74 [==============================] - 70s 942ms/step - loss: 0.4071 - accuracy: 0.8673 - val_loss: 2.7021 - val_accuracy: 0.3544
# Epoch 13/30
# 74/74 [==============================] - 70s 942ms/step - loss: 0.4257 - accuracy: 0.8583 - val_loss: 2.2385 - val_accuracy: 0.4372
# Epoch 14/30
# 74/74 [==============================] - 69s 933ms/step - loss: 0.2488 - accuracy: 0.9217 - val_loss: 2.1175 - val_accuracy: 0.4525
# Epoch 15/30
# 74/74 [==============================] - 69s 936ms/step - loss: 0.1862 - accuracy: 0.9405 - val_loss: 2.7064 - val_accuracy: 0.4051
# Epoch 16/30
# 74/74 [==============================] - 70s 943ms/step - loss: 0.1456 - accuracy: 0.9569 - val_loss: 2.3327 - val_accuracy: 0.4357
# Epoch 17/30
# 74/74 [==============================] - 69s 937ms/step - loss: 0.1284 - accuracy: 0.9624 - val_loss: 2.5827 - val_accuracy: 0.4550
# Epoch 18/30
# 74/74 [==============================] - 69s 933ms/step - loss: 0.0719 - accuracy: 0.9815 - val_loss: 2.3686 - val_accuracy: 0.4624
# Epoch 19/30
# 74/74 [==============================] - 69s 931ms/step - loss: 0.0552 - accuracy: 0.9867 - val_loss: 2.4879 - val_accuracy: 0.4701
# Epoch 20/30
# 74/74 [==============================] - 69s 938ms/step - loss: 0.0381 - accuracy: 0.9916 - val_loss: 2.5831 - val_accuracy: 0.4438
# Epoch 21/30
# 74/74 [==============================] - 69s 935ms/step - loss: 0.0243 - accuracy: 0.9944 - val_loss: 2.8036 - val_accuracy: 0.4441
# Epoch 22/30
# 74/74 [==============================] - 70s 942ms/step - loss: 0.0237 - accuracy: 0.9951 - val_loss: 2.9407 - val_accuracy: 0.4489
# Epoch 23/30
# 74/74 [==============================] - 69s 934ms/step - loss: 0.0243 - accuracy: 0.9939 - val_loss: 3.0054 - val_accuracy: 0.4352
# Epoch 24/30
# 74/74 [==============================] - 70s 939ms/step - loss: 0.0288 - accuracy: 0.9927 - val_loss: 3.7436 - val_accuracy: 0.3839
# Epoch 25/30
# 74/74 [==============================] - 69s 938ms/step - loss: 0.0721 - accuracy: 0.9782 - val_loss: 4.2807 - val_accuracy: 0.3445
# Epoch 26/30
# 74/74 [==============================] - 69s 937ms/step - loss: 0.3176 - accuracy: 0.9013 - val_loss: 4.1069 - val_accuracy: 0.3287
# Epoch 27/30
# 74/74 [==============================] - 70s 942ms/step - loss: 0.3552 - accuracy: 0.8862 - val_loss: 3.8840 - val_accuracy: 0.3732
# Epoch 28/30
# 74/74 [==============================] - 70s 940ms/step - loss: 0.0675 - accuracy: 0.9811 - val_loss: 2.5511 - val_accuracy: 0.4604
# Epoch 29/30
# 74/74 [==============================] - 70s 946ms/step - loss: 0.0289 - accuracy: 0.9942 - val_loss: 2.6813 - val_accuracy: 0.4507
# Epoch 30/30
# 74/74 [==============================] - 69s 938ms/step - loss: 0.0177 - accuracy: 0.9969 - val_loss: 2.8582 - val_accuracy: 0.4441
